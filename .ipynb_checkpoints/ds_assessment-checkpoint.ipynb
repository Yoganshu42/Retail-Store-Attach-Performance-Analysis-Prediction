# %%
import pandas as pd

df = pd.read_excel(r'attach_percentage.xls') # Changed name of excel file from Jumbo & Company_ Attach % to attach_percentage
df.sample(5)
# Out:
#         Branch             Store_Name   Dec   Nov   Oct   Sep   Aug
# 51   Telangana           Ts(Warangal)  0.13  0.03  0.04  0.00  0.00
# 101    Gujarat  Gandhinagar(Sargasan)  0.20  0.02  0.01  0.00  0.03
# 57   Delhi_Ncr     Up(Indirapuram) Br  0.13  0.24  0.18  0.15  0.03
# 135    Gujarat  Ahmedabad(Vishala) Br  0.09  0.12  0.16  0.17  0.08
# 69        Pune         Pune(Hadapsar)  0.33  0.62  0.71  0.67  0.60

# %%
df.shape
# Out:
# (163, 7)

# %%
df.isnull().any()
# Out:
# Branch        False
# Store_Name    False
# Dec           False
# Nov           False
# Oct           False
# Sep           False
# Aug           False
# dtype: bool

# %%
df.describe()
# Out:
#               Dec         Nov         Oct         Sep         Aug
# count  163.000000  163.000000  163.000000  163.000000  163.000000
# mean     0.217239    0.217117    0.170920    0.167301    0.128589
# std      0.173270    0.131246    0.116125    0.134518    0.116640
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.095000    0.130000    0.100000    0.080000    0.035000
# 50%      0.200000    0.200000    0.160000    0.150000    0.110000
# 75%      0.300000    0.295000    0.240000    0.245000    0.190000
# max      1.000000    0.700000    0.710000    0.800000    0.600000

# %%
months = ['Aug','Sep','Oct','Nov','Dec']
months_mean = df[months].mean()

# %%
df['avg_attach'] = df[months].mean(axis = 1)
df.sample(3)
# Out:
#         Branch           Store_Name   Dec   Nov   Oct   Sep   Aug  avg_attach
# 11   Delhi_Ncr     Delhi(Rohini) Br  0.31  0.36  0.27  0.09  0.15       0.236
# 123  Telangana       Ts(Hastinapur)  0.15  0.24  0.17  0.10  0.16       0.164
# 5         Pune  Pune(Nagar Road) Br  0.46  0.35  0.17  0.11  0.21       0.260

# %%
branch_perf = df.groupby('Branch')['avg_attach'].mean().sort_values(ascending = False)

# %%
top_stores = df.sort_values('avg_attach', ascending = False).head(10)
bottom_stores = df.sort_values('avg_attach').head(10)

# %%
top_stores
# Out:
#        Branch            Store_Name   Dec   Nov   Oct   Sep   Aug  avg_attach
# 10  Delhi_Ncr      Delhi(Hauz Khas)  0.63  0.60  0.52  0.80  0.56       0.622
# 69       Pune        Pune(Hadapsar)  0.33  0.62  0.71  0.67  0.60       0.586
# 64       Pune        Pune(Kondhawa)  0.48  0.61  0.35  0.35  0.28       0.414
# 81  Delhi_Ncr     Delhi(Budh Vihar)  0.45  0.44  0.45  0.42  0.19       0.390
# 17  Delhi_Ncr      Delhi(Daryaganj)  0.39  0.52  0.31  0.39  0.32       0.386
# 29       Pune     Pune(Dange Chowk)  0.58  0.70  0.56  0.00  0.00       0.368
# 7       Thane           Bhiwandi Br  0.44  0.44  0.33  0.21  0.39       0.362
# 91  Delhi_Ncr         Delhi(Narela)  0.75  0.29  0.43  0.00  0.32       0.358
# 21  Delhi_Ncr  Haryana(Mewla M.) Br  0.52  0.40  0.33  0.36  0.15       0.352
# 2   Delhi_Ncr  Up(Greater Noida) Br  0.25  0.36  0.30  0.41  0.43       0.350

# %%
bottom_stores
# Out:
#         Branch                        Store_Name  Dec   Nov   Oct   Sep  Aug  \
# 33      Mumbai                    MAHIM(VS Next)  0.0  0.00  0.00  0.00  0.0
# 85       Thane                       Currey Road  0.0  0.00  0.00  0.00  0.0
# 159      Thane                       Kharghar Br  0.0  0.00  0.00  0.00  0.0
# 162    Gujarat              Vadodara(Kothi Road)  0.0  0.00  0.00  0.00  0.0
# 160  Telangana  Ap(Tirupathi-Leela Mahal Circle)  0.0  0.00  0.00  0.00  0.0
# 161  Telangana                    Ap(Rajamundry)  0.0  0.00  0.00  0.00  0.0
# 155  Telangana                    Ap(Ntr Circle)  0.0  0.00  0.00  0.00  0.0
# 153     Mumbai                         Boisar Br  0.0  0.00  0.10  0.00  0.0
# 151      Thane                     Ulhasnagar Br  0.0  0.03  0.08  0.00  0.0
# 154  Telangana                         Ap(Vizag)  0.0  0.00  0.00  0.17  0.0
#
#      avg_attach
# 33        0.000
# 85        0.000
# 159       0.000
# 162       0.000
# 160       0.000
# 161       0.000
# 155       0.000
# 153       0.020
# 151       0.022
# 154       0.034

# %%
store_consistency = df.set_index('Store_Name')[['Aug','Sep','Oct','Nov','Dec']].agg(['mean','std'], axis=1)

# %%
store_consistency.sample(10)
# Out:
#                                mean       std
# Store_Name
# Boisar Br                     0.020  0.044721
# Haryana(Sec-65 Ext Gurugram)  0.234  0.061887
# Vadodara(Manjalpur) Br        0.106  0.104067
# Delhi(Narela)                 0.358  0.270684
# Ahmedabad(Krishna Nagar) Br   0.130  0.116404
# Delhi(Shahdara) Br            0.320  0.067823
# Andheri Br                    0.336  0.108995
# Vadodara(Kareli Baug)         0.118  0.066483
# Ts(Chintalkunta)              0.108  0.063008
# Ghodbunder Br                 0.186  0.078294

# %%
sc = store_consistency.copy()

# %%
q1,q3 = sc['mean'].quantile([0.25, 0.75])
std_mid = sc['std'].median()

# %%
sc['performance'] = pd.cut(
    sc['mean'],
    [-1, q1, q3, 1],
    labels = ['low', 'mid', 'high']
)

# %%
sc['consistency'] = sc['std'].le(std_mid).map({True:'Consistent', False:'Inconsistent'})
sc['segment'] = sc['performance'].astype(str) + ' + ' + sc['consistency']

# %%
sc.head()
# Out:
#                           mean       std performance   consistency  \
# Store_Name
# Delhi(Janakpuri) Br      0.210  0.041833         mid    Consistent
# Haryana(Gurgaon) Br      0.188  0.096799         mid  Inconsistent
# Up(Greater Noida) Br     0.350  0.075166        high    Consistent
# Pune(Bhosari) Br         0.294  0.092898        high  Inconsistent
# Ahmedabad(Maninagar) Br  0.164  0.039749         mid    Consistent
#
#                                      segment
# Store_Name
# Delhi(Janakpuri) Br         mid + Consistent
# Haryana(Gurgaon) Br       mid + Inconsistent
# Up(Greater Noida) Br       high + Consistent
# Pune(Bhosari) Br         high + Inconsistent
# Ahmedabad(Maninagar) Br     mid + Consistent

# %%
month_stats = df[['Aug','Sep','Oct','Nov','Dec']].aggregate(['mean','median','std'])
month_stats
# Out:
#              Aug       Sep       Oct       Nov       Dec
# mean    0.128589  0.167301  0.170920  0.217117  0.217239
# median  0.110000  0.150000  0.160000  0.200000  0.200000
# std     0.116640  0.134518  0.116125  0.131246  0.173270

# %%
month_long = df.melt(
    value_vars = ['Aug','Sep','Oct','Nov','Dec'],
    var_name = 'Month',
    value_name = 'Attach'
)

# %%
month_long.head()
# Out:
#   Month  Attach
# 0   Aug    0.24
# 1   Aug    0.04
# 2   Aug    0.43
# 3   Aug    0.32
# 4   Aug    0.17

# %%
month_dist = month_long.groupby('Month')['Attach'].agg(['mean','median','std'])

# %%
month_dist
# Out:
#            mean  median       std
# Month
# Aug    0.128589    0.11  0.116640
# Dec    0.217239    0.20  0.173270
# Nov    0.217117    0.20  0.131246
# Oct    0.170920    0.16  0.116125
# Sep    0.167301    0.15  0.134518

# %%
month_dist = month_dist.reindex(months)
month_dist['mean'].plot(kind='line', marker='o')
# Out:
# <Axes: xlabel='Month'>

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

months = ['Aug','Sep','Oct','Nov','Dec']
X = np.arange(1,6).reshape(-1,1)

# %%
def pred_jan(row):
    y = row[months].values
    model = LinearRegression()
    model.fit(X,y)
    return model.predict([[6]])[0]

df['Jan_Predicted_Attach'] = df.apply(pred_jan, axis=1)

# %%
df.head()
# Out:
#       Branch               Store_Name   Dec   Nov   Oct   Sep   Aug  \
# 0  Delhi_Ncr      Delhi(Janakpuri) Br  0.23  0.17  0.16  0.25  0.24
# 1  Delhi_Ncr      Haryana(Gurgaon) Br  0.21  0.26  0.15  0.28  0.04
# 2  Delhi_Ncr     Up(Greater Noida) Br  0.25  0.36  0.30  0.41  0.43
# 3       Pune         Pune(Bhosari) Br  0.33  0.33  0.36  0.13  0.32
# 4    Gujarat  Ahmedabad(Maninagar) Br  0.19  0.11  0.14  0.21  0.17
#
#    avg_attach  Jan_Predicted_Attach
# 0       0.210                 0.180
# 1       0.188                 0.284
# 2       0.350                 0.227
# 3       0.294                 0.360
# 4       0.164                 0.146

# %%
store_row = df.iloc[50]   # you can change index
y = store_row[months].values
jan_pred = store_row['Jan_Predicted_Attach']

x_hist = np.arange(1, 6)
x_full = np.arange(1, 7)
y_full = np.append(y, jan_pred)

import matplotlib.pyplot as plt

plt.figure()
plt.plot(x_hist, y, marker='o', label='Actual')
plt.plot(x_full, y_full, linestyle='--', marker='o', label='Jan Prediction')

plt.xticks(
    ticks=[1,2,3,4,5,6],
    labels=['Aug','Sep','Oct','Nov','Dec','Jan']
)

plt.xlabel('Month')
plt.ylabel('Attach %')
plt.title(f"Attach % Trend – {store_row['Store_Name']}")
plt.legend()
plt.show()

# %%
sel_months = ['Oct','Nov','Dec']
weights = np.array([0.2,0.3,0.5])
df['Jan_Weighted_Pred'] = df[sel_months].values@weights
df['Jan_Weighted_Pred'] = df['Jan_Weighted_Pred'].clip(0,1)

# %%
df.sample(10)
# Out:
#         Branch                Store_Name   Dec   Nov   Oct   Sep   Aug  \
# 14        Pune       Pune(Station Rd) Br  0.13  0.21  0.19  0.36  0.14
# 100  Telangana              Ts(Sun City)  0.20  0.36  0.18  0.08  0.00
# 35   Delhi_Ncr  Delhi(Model Town Iii) Br  0.46  0.26  0.29  0.26  0.29
# 127      Thane                  Thane Br  0.03  0.15  0.25  0.41  0.14
# 112     Mumbai    Ghatkopar(Lbs Marg) Br  0.09  0.12  0.06  0.00  0.10
# 45   Delhi_Ncr      Delhi(Vikas Marg) Br  0.32  0.37  0.40  0.28  0.31
# 13   Delhi_Ncr       Up(Raj Nagar Dc) Br  0.40  0.41  0.27  0.26  0.16
# 28   Delhi_Ncr      Delhi(Karol Bagh) Br  0.43  0.25  0.19  0.41  0.12
# 101    Gujarat     Gandhinagar(Sargasan)  0.20  0.02  0.01  0.00  0.03
# 66   Telangana              Ts(Kothapet)  0.25  0.32  0.20  0.08  0.15
#
#      avg_attach  Jan_Predicted_Attach  Jan_Weighted_Pred
# 14        0.206                 0.155              0.166
# 100       0.164                 0.368              0.244
# 35        0.312                 0.414              0.366
# 127       0.196                 0.052              0.110
# 112       0.074                 0.104              0.093
# 45        0.336                 0.369              0.351
# 13        0.300                 0.489              0.377
# 28        0.280                 0.418              0.328
# 101       0.052                 0.160              0.108
# 66        0.200                 0.332              0.261
